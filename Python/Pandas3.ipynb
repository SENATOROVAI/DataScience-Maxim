# %%
import pandas as pd
import numpy as np

# %%
sp = pd.Series([1, 2, 3, 4])
sp
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64

# %%
sp[[1, 2]]
# Out:
# 1    2
# 2    3
# dtype: int64

# %%
sp = pd.Series([1, 2, 3, 4], index=['a', 'b', 'c', 'd'])
sp[['a', 'c']]
# Out:
# a    1
# c    3
# dtype: int64

# %%
sp.index
# Out:
# Index(['a', 'b', 'c', 'd'], dtype='object')

# %%
dates = pd.date_range('2024-02-12','2024-02-19')
dates
# Out:
# DatetimeIndex(['2024-02-12', '2024-02-13', '2024-02-14', '2024-02-15',
#                '2024-02-16', '2024-02-17', '2024-02-18', '2024-02-19'],
#               dtype='datetime64[ns]', freq='D')

# %%
sp = pd.Series([*range(23, 31)], index=dates)
sp
# Out:
# 2024-02-12    23
# 2024-02-13    24
# 2024-02-14    25
# 2024-02-15    26
# 2024-02-16    27
# 2024-02-17    28
# 2024-02-18    29
# 2024-02-19    30
# Freq: D, dtype: int64

# %%
sp2 = pd.Series([*range(34,50,2)], index=dates)
sp2
# Out:
# 2024-02-12    34
# 2024-02-13    36
# 2024-02-14    38
# 2024-02-15    40
# 2024-02-16    42
# 2024-02-17    44
# 2024-02-18    46
# 2024-02-19    48
# Freq: D, dtype: int64

# %%
sp_diff = sp2 - sp
# Out:
# 11

# %% [markdown]
# Разница температур на конкретную дату

# %%
sp_diff['2024-02-12']
# Out:
# 11

# %%
# %%latex
# \begin{equation}
# \overline{x} = \frac{\sum_{i=1}^{n} x_i}{n}
# \end{equation}
# Out:
# \begin{equation}
# \overline{x} = \frac{\sum_{i=1}^{n} x_i}{n}
# \end{equation}

# %% [markdown]
# ![image.png](attachment:image.png)
