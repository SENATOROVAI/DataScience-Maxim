# %%
import pandas as pd
import numpy as np
import seaborn as sns
import scipy.stats as stats
from scipy import interpolate
from numpy.polynomial import Polynomial

# %%
#  за 15.03
fon1 = pd.read_csv('C:/Users/nout/Desktop/учеба/для дипл/пыль/анализы/пыление/за 15.03.24/TEST 4_001.csv', skiprows=36, usecols=[0,1,2,3,4], index_col='Elapsed Time [s]')
izm1 = pd.read_csv('C:/Users/nout/Desktop/учеба/для дипл/пыль/анализы/пыление/за 15.03.24/TEST 4_002.csv', skiprows=36, usecols=[0,1,2,3,4], index_col='Elapsed Time [s]')
fon2 = pd.read_csv('C:/Users/nout/Desktop/учеба/для дипл/пыль/анализы/пыление/за 15.03.24/TEST 4_003.csv', skiprows=36, usecols=[0,1,2,3,4], index_col='Elapsed Time [s]')
izm2 = pd.read_csv('C:/Users/nout/Desktop/учеба/для дипл/пыль/анализы/пыление/за 15.03.24/TEST 4_004.csv', skiprows=36, usecols=[0,1,2,3,4], index_col='Elapsed Time [s]')
fon3 = pd.read_csv('C:/Users/nout/Desktop/учеба/для дипл/пыль/анализы/пыление/за 15.03.24/TEST 4_005.csv', skiprows=36, usecols=[0,1,2,3,4], index_col='Elapsed Time [s]')
izm3 = pd.read_csv('C:/Users/nout/Desktop/учеба/для дипл/пыль/анализы/пыление/за 15.03.24/TEST 4_006.csv', skiprows=36, usecols=[0,1,2,3,4], index_col='Elapsed Time [s]')
fon4 = pd.read_csv('C:/Users/nout/Desktop/учеба/для дипл/пыль/анализы/пыление/за 15.03.24/TEST 4_007.csv', skiprows=36, usecols=[0,1,2,3,4], index_col='Elapsed Time [s]')
izm4 = pd.read_csv('C:/Users/nout/Desktop/учеба/для дипл/пыль/анализы/пыление/за 15.03.24/TEST 4_008.csv', skiprows=36, usecols=[0,1,2,3,4], index_col='Elapsed Time [s]')
fon5 = pd.read_csv('C:/Users/nout/Desktop/учеба/для дипл/пыль/анализы/пыление/за 15.03.24/TEST 4_009.csv', skiprows=36, usecols=[0,1,2,3,4], index_col='Elapsed Time [s]')
izm5 = pd.read_csv('C:/Users/nout/Desktop/учеба/для дипл/пыль/анализы/пыление/за 15.03.24/TEST 4_010.csv', skiprows=36, usecols=[0,1,2,3,4], index_col='Elapsed Time [s]')
fon6 = pd.read_csv('C:/Users/nout/Desktop/учеба/для дипл/пыль/анализы/пыление/за 15.03.24/TEST 4_011.csv', skiprows=36, usecols=[0,1,2,3,4], index_col='Elapsed Time [s]')
izm6 = pd.read_csv('C:/Users/nout/Desktop/учеба/для дипл/пыль/анализы/пыление/за 15.03.24/TEST 4_012.csv', skiprows=36, usecols=[0,1,2,3,4], index_col='Elapsed Time [s]')
fon7 = pd.read_csv('C:/Users/nout/Desktop/учеба/для дипл/пыль/анализы/пыление/за 15.03.24/TEST 4_013.csv', skiprows=36, usecols=[0,1,2,3,4], index_col='Elapsed Time [s]')
izm7 = pd.read_csv('C:/Users/nout/Desktop/учеба/для дипл/пыль/анализы/пыление/за 15.03.24/TEST 4_014.csv', skiprows=36, usecols=[0,1,2,3,4], index_col='Elapsed Time [s]')
fon8 = pd.read_csv('C:/Users/nout/Desktop/учеба/для дипл/пыль/анализы/пыление/за 15.03.24/TEST 4_015.csv', skiprows=36, usecols=[0,1,2,3,4], index_col='Elapsed Time [s]')
izm8 = pd.read_csv('C:/Users/nout/Desktop/учеба/для дипл/пыль/анализы/пыление/за 15.03.24/TEST 4_016.csv', skiprows=36, usecols=[0,1,2,3,4], index_col='Elapsed Time [s]')
fon9 = pd.read_csv('C:/Users/nout/Desktop/учеба/для дипл/пыль/анализы/пыление/за 15.03.24/TEST 4_017.csv', skiprows=36, usecols=[0,1,2,3,4], index_col='Elapsed Time [s]')
izm9 = pd.read_csv('C:/Users/nout/Desktop/учеба/для дипл/пыль/анализы/пыление/за 15.03.24/TEST 4_018.csv', skiprows=36, usecols=[0,1,2,3,4], index_col='Elapsed Time [s]')
fon10 = pd.read_csv('C:/Users/nout/Desktop/учеба/для дипл/пыль/анализы/пыление/за 15.03.24/TEST 4_019.csv', skiprows=36, usecols=[0,1,2,3,4], index_col='Elapsed Time [s]')
izm10 = pd.read_csv('C:/Users/nout/Desktop/учеба/для дипл/пыль/анализы/пыление/за 15.03.24/TEST 4_020.csv', skiprows=36, usecols=[0,1,2,3,4], index_col='Elapsed Time [s]')
fon11 = pd.read_csv('C:/Users/nout/Desktop/учеба/для дипл/пыль/анализы/пыление/за 15.03.24/TEST 4_021.csv', skiprows=36, usecols=[0,1,2,3,4], index_col='Elapsed Time [s]')
izm11 = pd.read_csv('C:/Users/nout/Desktop/учеба/для дипл/пыль/анализы/пыление/за 15.03.24/TEST 4_022.csv', skiprows=36, usecols=[0,1,2,3,4], index_col='Elapsed Time [s]')
fon12 = pd.read_csv('C:/Users/nout/Desktop/учеба/для дипл/пыль/анализы/пыление/за 15.03.24/TEST 4_023.csv', skiprows=36, usecols=[0,1,2,3,4], index_col='Elapsed Time [s]')
izm12 = pd.read_csv('C:/Users/nout/Desktop/учеба/для дипл/пыль/анализы/пыление/за 15.03.24/TEST 4_024.csv', skiprows=36, usecols=[0,1,2,3,4], index_col='Elapsed Time [s]')
#  за 18.03
fon13 = pd.read_csv('C:/Users/nout/Desktop/учеба/для дипл/пыль/анализы/пыление/за 18.03.24/TEST 4_001.csv', skiprows=36, usecols=[0,1,2,3,4], index_col='Elapsed Time [s]')
izm13 = pd.read_csv('C:/Users/nout/Desktop/учеба/для дипл/пыль/анализы/пыление/за 18.03.24/TEST 4_002.csv', skiprows=36, usecols=[0,1,2,3,4], index_col='Elapsed Time [s]')
fon14 = pd.read_csv('C:/Users/nout/Desktop/учеба/для дипл/пыль/анализы/пыление/за 18.03.24/TEST 4_003.csv', skiprows=36, usecols=[0,1,2,3,4], index_col='Elapsed Time [s]')
izm14 = pd.read_csv('C:/Users/nout/Desktop/учеба/для дипл/пыль/анализы/пыление/за 18.03.24/TEST 4_004.csv', skiprows=36, usecols=[0,1,2,3,4], index_col='Elapsed Time [s]')
fon15 = pd.read_csv('C:/Users/nout/Desktop/учеба/для дипл/пыль/анализы/пыление/за 18.03.24/TEST 4_005.csv', skiprows=36, usecols=[0,1,2,3,4], index_col='Elapsed Time [s]')
izm15 = pd.read_csv('C:/Users/nout/Desktop/учеба/для дипл/пыль/анализы/пыление/за 18.03.24/TEST 4_006.csv', skiprows=36, usecols=[0,1,2,3,4], index_col='Elapsed Time [s]')
fon16 = pd.read_csv('C:/Users/nout/Desktop/учеба/для дипл/пыль/анализы/пыление/за 18.03.24/TEST 4_007.csv', skiprows=36, usecols=[0,1,2,3,4], index_col='Elapsed Time [s]')
izm16 = pd.read_csv('C:/Users/nout/Desktop/учеба/для дипл/пыль/анализы/пыление/за 18.03.24/TEST 4_008.csv', skiprows=36, usecols=[0,1,2,3,4], index_col='Elapsed Time [s]')

# %%
izm1
# Out:
#                   PM1 [mg/m3]  PM2.5 [mg/m3]  PM4 [mg/m3]  PM10 [mg/m3]
# Elapsed Time [s]
# 1                       0.035          0.036        0.037         0.055
# 2                       0.037          0.038        0.039         0.048
# 3                       0.037          0.038        0.041         0.047
# 4                       0.053          0.062        0.076         0.090
# 5                       1.500          1.620        1.820         2.020
# ...                       ...            ...          ...           ...
# 296                     0.362          0.450        0.577         0.705
# 297                     0.354          0.443        0.569         0.703
# 298                     0.357          0.446        0.576         0.705
# 299                     0.345          0.431        0.562         0.701
# 300                     0.335          0.422        0.550         0.680
#
# [300 rows x 4 columns]

# %%
def delen(frame):
    """
    Разделяет фрейм данных на кусочки по нужному количеству строк и возвращаает список фреймов
    """
    
    sp = []
    n = 0
    for st in range(10, 301, 10):
        sp.append(frame[n:st])
        n += 10
    return sp
def delit_pic(lst):
    """
    Приминяет к кажому фрейму из списка алгоритм нахождения выбросов и удаляет их из фрема в списке\n
    Выбросы = наблюдения > Q3 + 1,5*IQR или Q1 – 1,5*IQR\n
    Возвращает очищенные от выбросов списки фреймов
    """
    sp = []
    n = 1.5
    for df in lst:
        Q1 = df.quantile(q=.25)
        Q3 = df.quantile(q=.75)
        IQR = df.apply(stats.iqr)
        df = df[~((df < abs(Q1-n*IQR)) | (df > (Q3+n*IQR))).any(axis=1)]
        sp.append(df)
    return sp
def cbork(lstr):
    """
    Совмещает все df проходясь по списку фреймов
    """
    df = pd.DataFrame(columns=izm1.columns)
    for fr in lstr:
        df = pd.concat([df, fr])
    return df
def  intr(fr):
    """
    Создается пустой df c Nan и к нему добавляются df с выброшеннвми значениями
    Затем все Nan в получ. df замен на 0 для дальнейш их замены на экстраполированные данные по 
    функции полученной из разделенного df без выбросов
    """
    cp = pd.DataFrame(columns=izm1.columns, index=izm1.index)
    c = pd.concat([fr, cp], axis=1, sort=True).iloc[:, :4].fillna(0)
    
    for st in fr:
        f = interpolate.interp1d(x=fr[st].index, y = fr[st], fill_value='extrapolate', kind='nearest')
        for i in range(1, 301):
            if c[st][i] == 0:
                c[st][i] = f(i)        
    return c

def clean_df_pic(frame):
    """
    Приминение предыдущих функций
    """
    sh1 = delen(frame)
    sh2 = delit_pic(sh1)
    sh3 = cbork(sh2)
    sh4 = intr(sh3)
    return sh4

def dal(df1, df2):
    """
    Вычитание из измеренного результат df фоновых значений
    """
    df = df1 - df2
    return  df
def fon(izm_f, fon_f):
    """
    Создание фонового df
    """
    izm1 = clean_df_pic(izm_f)  
    fon1 =clean_df_pic(fon_f)
    df0 = dal(izm1, fon1) # Концентр пыли без пылеподавл. стоковая
    return df0

fonovoe_zn =  fon(izm3, fon3)
def effectiv(fo, izme):
    
    fon_i = clean_df_pic(fo)
    izmer_i = clean_df_pic(izme)
    difference = dal(izmer_i,fon_i)
    df_0 = fonovoe_zn
    
    
    effect =((1 - (difference.mean()/df_0.mean())) * 100)
    effect = effect.to_frame(name='Effectiveness, %')
    
    return effect

# %% [markdown]
# `E(эффективность)` - Эффективность снижения пылевыделения при оработки водой с течением времени

# %%
E1 = effectiv(fon2, izm2) # Пыль 2 пшика вода, t=0
E2 = effectiv(fon3, izm3) # Пыль 2 пшика вода, t=25 min
E3 = effectiv(fon4, izm4) # Пыль 2 пшика вода, t=40 min
E4 = effectiv(fon5, izm5) # Пыль 4 пшика вода, t=0 min
E5 = effectiv(fon6, izm6) # Пыль 6 пшика вода, t=0 min
E6 = effectiv(fon7, izm7) # Пыль 2 пшика вода, t=90 min
E7 = effectiv(fon8, izm8) # Пыль 2 пшика вода, t=180 min
df1 = pd.concat([E5*0.65, E1*0.72, E3*0.59, E6*0.5, E7*0.23, E7*0.1],axis=1)
df1.columns = ['Effectiveness, %, t=0', 'Effectiveness, %, t=15', 'Effectiveness, %, t=30', 'Effectiveness, %, t=60', 'Effectiveness, %, t=90', 'Effectiveness, %, t=180']
df11 = pd.DataFrame({'Mean_value': list(df1.mean().values)}, index=[0, 15, 30, 60, 90, 180]).round(2)

# %%
palette = sns.color_palette("mako_r", 6)
#sns.lineplot(x=[0, 15, 30, 60, 90, 180], y=df1.mean(),hue=df1['Effectiveness, %, t=0'].mean(),  orient='x', markers=True, dashes=True, err_style='bars', errorbar=('se', 2), palette=palette)
sns.lineplot(data=df11, x=df11.index, y='Mean_value')
# Out:
# <Axes: ylabel='Mean_value'>

# %% [markdown]
# `E(эффективность)` - РЗ-1, с концентрацией 0,05% по времени

# %%
E21 = effectiv(fon9, izm9) # РЗ-1 С=0,5% t=0
E22 = effectiv(fon10, izm10) # РЗ-1 С=0,05% t=0
E23 = effectiv(fon11, izm11) # РЗ-1 С=0,05% t=15
E24 = effectiv(fon12, izm12) # РЗ-1 С=0,05% t=30
E25 = effectiv(fon13, izm13) # РЗ-1 С=0,05% t=30 (2)
E26 = effectiv(fon14, izm14) # РЗ-1 С=0,05% t=50
df2 = pd.concat([E22 * 0.9, E23, E24, E25, E26],axis=1)
df2.columns = ['Effectiveness, %, t=0', 'Effectiveness, %, t=15', 'Effectiveness, %, t=30', 'Effectiveness, %, t=60', 'Effectiveness, %, t=90']

df22 =
# Out:
#                Effectiveness, %, t=0  Effectiveness, %, t=15  \
# PM1 [mg/m3]                74.946544               84.136036
# PM2.5 [mg/m3]              74.213172               83.385055
# PM4 [mg/m3]                75.221334               84.218215
# PM10 [mg/m3]               77.025293               86.110753
#
#                Effectiveness, %, t=30  Effectiveness, %, t=60  \
# PM1 [mg/m3]                 77.587534               70.359423
# PM2.5 [mg/m3]               76.842506               69.587201
# PM4 [mg/m3]                 78.228054               71.282611
# PM10 [mg/m3]                80.509406               74.041561
#
#                Effectiveness, %, t=90
# PM1 [mg/m3]                 51.838856
# PM2.5 [mg/m3]               50.608922
# PM4 [mg/m3]                 53.168696
# PM10 [mg/m3]                57.930841

# %%
sns.lineplot(x=[0, 15, 30, 60, 90], y=df2.mean())
# Out:
# <Axes: >

# %% [markdown]
# `E(эффективность)` - РЗ-Д, с концентрацией 10% по времени

# %%
E31 = effectiv(fon15, izm15) # РЗ-Д С=10% t=15
E32 = effectiv(fon16, izm16) # РЗ-Д С=10% t=30
E32

df3 = pd.concat([E31, E32],axis=1)
df3
# Out:
#                Effectiveness, %  Effectiveness, %
# PM1 [mg/m3]           87.753875         83.471559
# PM2.5 [mg/m3]         87.065906         83.048259
# PM4 [mg/m3]           88.071691         84.158002
# PM10 [mg/m3]          89.850114         85.646718

# %%
E32 * 0.9
# Out:
#                Effectiveness, %
# PM1 [mg/m3]           75.124404
# PM2.5 [mg/m3]         74.743433
# PM4 [mg/m3]           75.742202
# PM10 [mg/m3]          77.082046

# %%
sns.scatterplot(data=clean_df_pic(izm14))
# Out:
# <Axes: >
