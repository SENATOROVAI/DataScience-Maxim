# %%
import pandas as pd
import numpy as np

# %%
fon1 = pd.read_csv('C:/Users/nout/Desktop/попытка номер 5/Уроки/GitHub/Python-Maksim/Dust/Data/TEST_5_001 (1).csv', skiprows=36, index_col='Elapsed Time [s]')
izm1 = pd.read_csv('C:/Users/nout/Desktop/попытка номер 5/Уроки/GitHub/Python-Maksim/Dust/Data/TEST_5_002.csv', skiprows=36, index_col='Elapsed Time [s]')
fon1.head()
# Out:
#                   PM1 [mg/m3]  PM2.5 [mg/m3]  PM4 [mg/m3]  PM10 [mg/m3]  \
# Elapsed Time [s]
# 1                       0.027          0.029        0.035         0.083
# 2                       0.026          0.028        0.031         0.057
# 3                       0.023          0.024        0.027         0.037
# 4                       0.041          0.046        0.060         0.124
# 5                       1.390          1.450        1.680         2.730
#
#                   TOTAL [mg/m3] Alarms  Errors
# Elapsed Time [s]
# 1                         0.185    NaN     NaN
# 2                         0.092    NaN     NaN
# 3                         0.037    NaN     NaN
# 4                         0.131    NaN     NaN
# 5                         2.880    PM1     NaN

# %%
izm1.head()
# Out:
#                   PM1 [mg/m3]  PM2.5 [mg/m3]  PM4 [mg/m3]  PM10 [mg/m3]  \
# Elapsed Time [s]
# 1                       0.075          0.085        0.115         0.245
# 2                       0.084          0.093        0.119         0.257
# 3                       0.080          0.091        0.122         0.252
# 4                       0.072          0.082        0.117         0.243
# 5                       0.070          0.080        0.111         0.237
#
#                   TOTAL [mg/m3]  Alarms  Errors
# Elapsed Time [s]
# 1                         0.265     NaN     NaN
# 2                         0.281     NaN     NaN
# 3                         0.347     NaN     NaN
# 4                         0.287     NaN     NaN
# 5                         0.275     NaN     NaN

# %%
fon1 = fon1.drop(['Alarms','Errors'], axis=1)
izm1 = izm1.drop(['Alarms','Errors'], axis=1)

# %%
desp = - izm1 + fon1
desp
# Out:
#                   PM1 [mg/m3]  PM2.5 [mg/m3]  PM4 [mg/m3]  PM10 [mg/m3]  \
# Elapsed Time [s]
# 1                      -0.048         -0.056       -0.080        -0.162
# 2                      -0.058         -0.065       -0.088        -0.200
# 3                      -0.057         -0.067       -0.095        -0.215
# 4                      -0.031         -0.036       -0.057        -0.119
# 5                       1.320          1.370        1.569         2.493
# ...                       ...            ...          ...           ...
# 296                     0.743          0.894        1.367         3.313
# 297                     0.731          0.884        1.347         3.366
# 298                     0.741          0.894        1.376         3.175
# 299                     0.751          0.899        1.377         3.096
# 300                     0.791          0.942        1.429         3.219
#
#                   TOTAL [mg/m3]
# Elapsed Time [s]
# 1                        -0.080
# ...

# %%
#desp.sample(20)

# %%
desp.apply(lambda x: x + 10 if x > 0 else x, axis=1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17140\877089131.py in ?()
# ----> 1 desp.apply(lambda x: x + 10 if x > 0 else x, axis=1)
#
# c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py in ?(self, func, axis, raw, result_type, args, **kwargs)
#    9419             result_type=result_type,
#    9420             args=args,
#    9421             kwargs=kwargs,
#    9422         )
# -> 9423         return op.apply().__finalize__(self, method="apply")
#
# c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\apply.py in ?(self)
#     674         # raw
#     675         elif self.raw:
#     676             return self.apply_raw()
#     677
# --> 678         return self.apply_standard()
#
# c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\apply.py in ?(self)
#     797     def apply_standard(self):
# ...
